# %% [markdown]
# <span style="font-size: larger;">**Φόρτωση δεδομένων**</span></br>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Φορτώνουμε τα δεδομένα από το αρχείο
df = pd.read_csv('data.csv')

# Ορίζουμε τις στήλες A, B και C
A = df['A'] # Πίνακας που έχει τα x
B = df['B'] # Πίνακας που έχει τα fΒ
C = df['C'] # Πίνακας που έχει τα fC

# %% [markdown]
# ---
# <span style="font-size: larger;">**Γραφική Παράσταση του $𝑓$**</span><sub>***B***</sub> $(x)$ , <span style="font-size: smaller;">ώπου το $x$ παίρνει τιμές από την στήλη Α</span></br>

# %%
plt.scatter(A, B, label='B')

# Μια προσέγκιση της συνάρτησης που ψάχνουμε
# (δεν ήταν απαραίτητο να γίνει, μπορούν οι επόμενες 2 γραμμές να αφαιρεθούν αν δεν χρειάζονται)
x = np.linspace(min(A), max(A), 100)
plt.plot(x, 2.25*np.log10(x), color='red', label='log10')

plt.xlabel('A')
plt.ylabel('B')
plt.legend()
plt.show()

# %% [markdown]
# <span style="font-size: larger;">**ΣΥΜΠΕΡΑΣΜΑ**</span></br>
# Παρατηρούμε ότι βάζοντας τις τιμές του Α στον άξονα x'x και τις τιμές του Β στον άξονα y'y καταλήγουμε σε μία συνάρτηση <span style="font-family: 'Times New Roman'; font-size: 18px;">**λογαριθμικού**</span> τύπου.</br>
# <span style="font-size: smaller;">Παρακάτω φαίνεται ένα παράδειγμα γραφικής παράστασης μιας <span style="font-family: 'Times New Roman'; font-size: 14px;">**λογαριθμικής**</span> συνάρτησης:</span>

# %%
x_values = np.linspace(1, 1000, 100)
y_values = np.log10(x_values)

plt.plot(x_values, y_values, color='red', label='log(x)')

plt.xlabel('x')
plt.ylabel('log10(x)')
plt.legend()
plt.show()

# %% [markdown]
# ---
# <span style="font-size: larger;">**Γραφική Παράσταση του $𝑓$**</span><sub>***C***</sub> $(x)$ , <span style="font-size: smaller;">ώπου το $x$ παίρνει τιμές από την στήλη Α</span></br>

# %%
plt.scatter(A, C, label='C')

# Μια προσέγκιση της συνάρτησης που ψάχνουμε
# (δεν ήταν απαραίτητο να γίνει, μπορούν οι επόμενες 2 γραμμές να αφαιρεθούν αν δεν χρειάζονται)
x = np.linspace(min(A), max(A), 100)
plt.plot(x, np.cbrt(x), color='red', label='cbrt')

plt.xlabel('A')
plt.ylabel('C')
plt.legend()
plt.show()

# %% [markdown]
# <span style="font-size: larger;">**ΣΥΜΠΕΡΑΣΜΑ**</span></br>
# Παρατηρούμε ότι βάζοντας τις τιμές του Α στον άξονα x'x και τις τιμές του C στον άξονα y'y καταλήγουμε σε μία συνάρτηση τύπου <span style="font-family: 'Times New Roman'; font-size: 18px;">**κυβικής ρίζας**</span>.</br>
# <span style="font-size: smaller;">Παρακάτω φαίνεται ένα παράδειγμα γραφικής παράστασης της <span style="font-family: 'Times New Roman'; font-size: 14px;">**κυβικής ρίζας**</span>:</span>

# %%
x_values = np.linspace(2, 1000, 100)

y_values = np.cbrt(x_values)

plt.plot(x_values, y_values, color='red', label='cbrt(x)')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Σχεδίαση Κυβικής Ρίζας του x')
plt.legend()
plt.show()
